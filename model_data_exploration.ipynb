# %%
import pandas as pd

df = pd.read_csv('processed_data.csv')

df = df[df['HHFAMINC'] > 0].reset_index()

display(df)
print(df.columns)
# Out:
#       index     HOUSEID  ANNMILES      GASUSGE  HighestEDUC  TAXISERVICE  \
# 0         0  9000013002     12000   408.258158            7            0
# 1         1  9000013016     10000   356.835885            6            0
# 2         2  9000013039      5000   171.387563            6            0
# 3         3  9000013041      5000   173.118751            6            0
# 4         4  9000013042     70020  2414.157750            8            0
# ...     ...         ...       ...          ...          ...          ...
# 7066   7161  9000218006     11000   374.625041            7            0
# 7067   7162  9000218013      3000   102.395445            7            0
# 7068   7163  9000218021     12100   421.380431            6            0
# 7069   7164  9000218034     10000   482.619553            2            0
# 7070   7165  9000218040     14000   736.301892            4            0
#
#       RIDESHARE22  ESCOOTERUSED  PTUSED  MCTRANSIT  ...  URBAN  URBANSIZE  \
# 0               0             0       0          0  ...      1          4
# 1               0             0       0          0  ...      1          2
# 2               0             0       0          0  ...      1          4
# 3               0             0       0          0  ...      1          3
# 4               3             0       8          0  ...      1          4
# ...           ...           ...     ...        ...  ...    ...        ...
# 7066            0             0       0          0  ...      1          3
# 7067            0             0       0          0  ...      1          1
# 7068            0             0       0          0  ...      4          6
# 7069            0             0       0          0  ...      4          6
# 7070            0             0       0          0  ...      4          6
#
#       URBRUR  PPT517  YOUNGCHILD  RESP_CNT  URBRUR_2010  TDAYDATE  WRKCOUNT  \
# 0          1       2           0         4            1    202202         1
# 1          1       0           0         2            1    202202         2
# 2          1       2           0         4            1    202201         1
# 3          1       0           0         1            1    202201         1
# 4          1       0           1         2            1    202202         2
# ...      ...     ...         ...       ...          ...       ...       ...
# 7066       1       2           0         3            1    202212         1
# 7067       1       0           0         2            1    202301         0
# 7068       2       0           0         1            2    202212         0
# 7069       2       0           0         2            2    202212         0
# 7070       2       0           0         1            2    202212         1
#
#       STRATUMID
# 0          1021
# 1          1021
# 2          1021
# 3          1021
# 4          1021
# ...         ...
# 7066       1031
# 7067       1031
# 7068       1032
# 7069       1032
# 7070       1032
#
# [7071 rows x 47 columns]
# Index(['index', 'HOUSEID', 'ANNMILES', 'GASUSGE', 'HighestEDUC', 'TAXISERVICE',
#        'RIDESHARE22', 'ESCOOTERUSED', 'PTUSED', 'MCTRANSIT', 'WALKTRANSIT',
#        'BIKETRANSIT', 'EMPLOYMENT2', 'WTHHFIN', 'WTHHFIN5D', 'WTHHFIN2D',
#        'NUMADLT', 'HOMEOWN', 'HOMETYPE', 'RAIL', 'CENSUS_D', 'CENSUS_R',
#        'HH_HISP', 'DRVRCNT', 'CNTTDHH', 'CDIVMSAR', 'FLAG100', 'HHFAMINC',
#        'HHFAMINC_IMP', 'HH_RACE', 'HHSIZE', 'HHVEHCNT', 'HHRELATD', 'LIF_CYC',
#        'MSACAT', 'MSASIZE', 'TRAVDAY', 'URBAN', 'URBANSIZE', 'URBRUR',
#        'PPT517', 'YOUNGCHILD', 'RESP_CNT', 'URBRUR_2010', 'TDAYDATE',
#        'WRKCOUNT', 'STRATUMID'],
#       dtype='object')

# %%
numerical = [
            'TAXISERVICE', 'ESCOOTERUSED', 'PTUSED', 'MCTRANSIT', 'WALKTRANSIT',
            'BIKETRANSIT', 'EMPLOYMENT2', 'WTHHFIN', 'WTHHFIN5D', 'WTHHFIN2D',
            'CNTTDHH', 'PPT517', 'YOUNGCHILD', 'RESP_CNT','WRKCOUNT', 'NUMADLT',
            'RIDESHARE22', 'DRVRCNT', 'HHSIZE', 'HHVEHCNT'
            ]

categorical = [
                'HighestEDUC', 'HOMEOWN', 'HOMETYPE', 'TRAVDAY', 
                'RAIL', 'CENSUS_D', 'CENSUS_R', 'HH_HISP',
                'FLAG100', 'HHFAMINC', 'HHFAMINC_IMP', 'HH_RACE', 'CDIVMSAR', 
                'HHRELATD', 'LIF_CYC', 'MSACAT', 'MSASIZE',
                'URBAN', 'URBANSIZE', 'URBRUR', 'URBRUR_2010', 
               ]

# %%
for i in range(len(df)):
    if (df['HH_RACE'][i] == 97):
        df['HH_RACE'][i] = 7

for i in range(len(df)):
    df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# Out:
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HH_RACE'][i] = 7
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10
# C:\Users\Razer\AppData\Local\Temp\ipykernel_18092\767267859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CDIVMSAR'][i] = df['CDIVMSAR'][i] - 10

# %%
import numpy as np
import torch

df_categorical = {}
freature_lengths = {}

for colu in categorical:
    df_categorical[colu] = []

for i in range(len(df)):
    for colu in categorical:
        freature_lengths[colu] = df[colu].max()
        df_categorical[colu].append(torch.zeros(df[colu].max()))
        vec = torch.zeros(df[colu].max())

        vec[df[colu][i] - 1] = 1
        df_categorical[colu][i] = vec

df_categorical = pd.DataFrame(df_categorical)

# %%
display(df_categorical)
df_categorical.columns
# Out:
#                                             HighestEDUC  \
# 0     [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 1     [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 2     [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 3     [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 4     [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# ...                                                 ...
# 7066  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7067  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7068  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7069  [tensor(0.), tensor(1.), tensor(0.), tensor(0....
# 7070  [tensor(0.), tensor(0.), tensor(0.), tensor(1....
#
#                                                HOMEOWN  \
# 0     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 1     [tensor(0.), tensor(0.), tensor(1.), tensor(0.)]
# 2     [tensor(0.), tensor(0.), tensor(1.), tensor(0.)]
# 3     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 4     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# ...                                                ...
# 7066  [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 7067  [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 7068  [tensor(0.), tensor(1.), tensor(0.), tensor(0.)]
# 7069  [tensor(0.), tensor(1.), tensor(0.), tensor(0.)]
# 7070  [tensor(0.), tensor(1.), tensor(0.), tensor(0.)]
#
#                                                HOMETYPE  \
# 0     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 1     [tensor(0.), tensor(0.), tensor(1.), tensor(0....
# 2     [tensor(0.), tensor(0.), tensor(1.), tensor(0....
# 3     [tensor(0.), tensor(1.), tensor(0.), tensor(0....
# 4     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# ...                                                 ...
# 7066  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 7067  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 7068  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 7069  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 7070  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
#
#                                                 TRAVDAY  \
# 0     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 1     [tensor(0.), tensor(0.), tensor(0.), tensor(1....
# 2     [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 3     [tensor(0.), tensor(1.), tensor(0.), tensor(0....
# 4     [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# ...                                                 ...
# 7066  [tensor(0.), tensor(1.), tensor(0.), tensor(0....
# 7067  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7068  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 7069  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7070  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
#
#                           RAIL  \
# 0     [tensor(1.), tensor(0.)]
# 1     [tensor(0.), tensor(1.)]
# 2     [tensor(1.), tensor(0.)]
# 3     [tensor(0.), tensor(1.)]
# 4     [tensor(1.), tensor(0.)]
# ...                        ...
# 7066  [tensor(0.), tensor(1.)]
# 7067  [tensor(0.), tensor(1.)]
# 7068  [tensor(0.), tensor(1.)]
# 7069  [tensor(0.), tensor(1.)]
# 7070  [tensor(0.), tensor(1.)]
#
#                                                CENSUS_D  \
# 0     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 1     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 2     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 3     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 4     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# ...                                                 ...
# 7066  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7067  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7068  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7069  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7070  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
#
#                                               CENSUS_R  \
# 0     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 1     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 2     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 3     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 4     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# ...                                                ...
# 7066  [tensor(0.), tensor(0.), tensor(1.), tensor(0.)]
# 7067  [tensor(0.), tensor(0.), tensor(1.), tensor(0.)]
# 7068  [tensor(0.), tensor(0.), tensor(1.), tensor(0.)]
# 7069  [tensor(0.), tensor(0.), tensor(1.), tensor(0.)]
# 7070  [tensor(0.), tensor(0.), tensor(1.), tensor(0.)]
#
#                        HH_HISP                   FLAG100  \
# 0     [tensor(0.), tensor(1.)]  [tensor(1.), tensor(0.)]
# 1     [tensor(0.), tensor(1.)]  [tensor(1.), tensor(0.)]
# 2     [tensor(0.), tensor(1.)]  [tensor(1.), tensor(0.)]
# 3     [tensor(0.), tensor(1.)]  [tensor(1.), tensor(0.)]
# 4     [tensor(0.), tensor(1.)]  [tensor(1.), tensor(0.)]
# ...                        ...                       ...
# 7066  [tensor(0.), tensor(1.)]  [tensor(1.), tensor(0.)]
# 7067  [tensor(0.), tensor(1.)]  [tensor(1.), tensor(0.)]
# 7068  [tensor(0.), tensor(1.)]  [tensor(1.), tensor(0.)]
# 7069  [tensor(0.), tensor(1.)]  [tensor(1.), tensor(0.)]
# 7070  [tensor(0.), tensor(1.)]  [tensor(1.), tensor(0.)]
#
#                                                HHFAMINC  ...  \
# 0     [tensor(0.), tensor(0.), tensor(0.), tensor(0....  ...
# 1     [tensor(0.), tensor(0.), tensor(0.), tensor(0....  ...
# 2     [tensor(0.), tensor(0.), tensor(0.), tensor(0....  ...
# 3     [tensor(0.), tensor(0.), tensor(0.), tensor(0....  ...
# 4     [tensor(0.), tensor(0.), tensor(0.), tensor(0....  ...
# ...                                                 ...  ...
# 7066  [tensor(0.), tensor(0.), tensor(0.), tensor(0....  ...
# 7067  [tensor(0.), tensor(0.), tensor(1.), tensor(0....  ...
# 7068  [tensor(0.), tensor(0.), tensor(0.), tensor(1....  ...
# 7069  [tensor(0.), tensor(0.), tensor(0.), tensor(1....  ...
# 7070  [tensor(0.), tensor(0.), tensor(0.), tensor(0....  ...
#
#                                                 HH_RACE  \
# 0     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 1     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 2     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 3     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 4     [tensor(0.), tensor(0.), tensor(1.), tensor(0....
# ...                                                 ...
# 7066  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 7067  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 7068  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 7069  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 7070  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
#
#                                                CDIVMSAR  \
# 0     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 1     [tensor(0.), tensor(0.), tensor(1.), tensor(0....
# 2     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 3     [tensor(0.), tensor(1.), tensor(0.), tensor(0....
# 4     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# ...                                                 ...
# 7066  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7067  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7068  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7069  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7070  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
#
#                       HHRELATD  \
# 0     [tensor(1.), tensor(0.)]
# 1     [tensor(1.), tensor(0.)]
# 2     [tensor(1.), tensor(0.)]
# 3     [tensor(0.), tensor(1.)]
# 4     [tensor(1.), tensor(0.)]
# ...                        ...
# 7066  [tensor(1.), tensor(0.)]
# 7067  [tensor(1.), tensor(0.)]
# 7068  [tensor(0.), tensor(1.)]
# 7069  [tensor(1.), tensor(0.)]
# 7070  [tensor(0.), tensor(1.)]
#
#                                                 LIF_CYC  \
# 0     [tensor(0.), tensor(0.), tensor(0.), tensor(1....
# 1     [tensor(0.), tensor(1.), tensor(0.), tensor(0....
# 2     [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 3     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 4     [tensor(0.), tensor(0.), tensor(0.), tensor(1....
# ...                                                 ...
# 7066  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7067  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7068  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7069  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7070  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
#
#                                                 MSACAT  \
# 0     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 1     [tensor(0.), tensor(0.), tensor(1.), tensor(0.)]
# 2     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 3     [tensor(0.), tensor(1.), tensor(0.), tensor(0.)]
# 4     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# ...                                                ...
# 7066  [tensor(0.), tensor(1.), tensor(0.), tensor(0.)]
# 7067  [tensor(0.), tensor(0.), tensor(1.), tensor(0.)]
# 7068  [tensor(0.), tensor(0.), tensor(1.), tensor(0.)]
# 7069  [tensor(0.), tensor(0.), tensor(0.), tensor(1.)]
# 7070  [tensor(0.), tensor(0.), tensor(0.), tensor(1.)]
#
#                                                 MSASIZE  \
# 0     [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 1     [tensor(0.), tensor(0.), tensor(1.), tensor(0....
# 2     [tensor(0.), tensor(0.), tensor(0.), tensor(1....
# 3     [tensor(0.), tensor(0.), tensor(0.), tensor(1....
# 4     [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# ...                                                 ...
# 7066  [tensor(0.), tensor(0.), tensor(0.), tensor(1....
# 7067  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 7068  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 7069  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7070  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
#
#                                                  URBAN  \
# 0     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 1     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 2     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 3     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 4     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# ...                                                ...
# 7066  [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 7067  [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 7068  [tensor(0.), tensor(0.), tensor(0.), tensor(1.)]
# 7069  [tensor(0.), tensor(0.), tensor(0.), tensor(1.)]
# 7070  [tensor(0.), tensor(0.), tensor(0.), tensor(1.)]
#
#                                               URBANSIZE  \
# 0     [tensor(0.), tensor(0.), tensor(0.), tensor(1....
# 1     [tensor(0.), tensor(1.), tensor(0.), tensor(0....
# 2     [tensor(0.), tensor(0.), tensor(0.), tensor(1....
# 3     [tensor(0.), tensor(0.), tensor(1.), tensor(0....
# 4     [tensor(0.), tensor(0.), tensor(0.), tensor(1....
# ...                                                 ...
# 7066  [tensor(0.), tensor(0.), tensor(1.), tensor(0....
# 7067  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 7068  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7069  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7070  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
#
#                         URBRUR               URBRUR_2010
# 0     [tensor(1.), tensor(0.)]  [tensor(1.), tensor(0.)]
# 1     [tensor(1.), tensor(0.)]  [tensor(1.), tensor(0.)]
# 2     [tensor(1.), tensor(0.)]  [tensor(1.), tensor(0.)]
# 3     [tensor(1.), tensor(0.)]  [tensor(1.), tensor(0.)]
# 4     [tensor(1.), tensor(0.)]  [tensor(1.), tensor(0.)]
# ...                        ...                       ...
# 7066  [tensor(1.), tensor(0.)]  [tensor(1.), tensor(0.)]
# 7067  [tensor(1.), tensor(0.)]  [tensor(1.), tensor(0.)]
# 7068  [tensor(0.), tensor(1.)]  [tensor(0.), tensor(1.)]
# 7069  [tensor(0.), tensor(1.)]  [tensor(0.), tensor(1.)]
# 7070  [tensor(0.), tensor(1.)]  [tensor(0.), tensor(1.)]
#
# [7071 rows x 21 columns]
# Index(['HighestEDUC', 'HOMEOWN', 'HOMETYPE', 'TRAVDAY', 'RAIL', 'CENSUS_D',
#        'CENSUS_R', 'HH_HISP', 'FLAG100', 'HHFAMINC', 'HHFAMINC_IMP', 'HH_RACE',
#        'CDIVMSAR', 'HHRELATD', 'LIF_CYC', 'MSACAT', 'MSASIZE', 'URBAN',
#        'URBANSIZE', 'URBRUR', 'URBRUR_2010'],
#       dtype='object')

# %%
df_numerical = {}

for colu in numerical:
    df_numerical[colu] = []

for i in range(len(df)):
    for colu in numerical:
        df_numerical[colu].append(df[colu][i])

df_numerical = pd.DataFrame(df_numerical)

# %%
display(df_numerical)
df_numerical.columns
# Out:
#       TAXISERVICE  ESCOOTERUSED  PTUSED  MCTRANSIT  WALKTRANSIT  BIKETRANSIT  \
# 0               0             0       0          0           13            0
# 1               0             0       0          0            7            0
# 2               0             0       0          0            8            0
# 3               0             0       0          0            0            0
# 4               0             0       8          0            9            0
# ...           ...           ...     ...        ...          ...          ...
# 7066            0             0       0          0            0            0
# 7067            0             0       0          0            3            0
# 7068            0             0       0          0            0            0
# 7069            0             0       0          0            0            0
# 7070            0             0       0          0            5            0
#
#       EMPLOYMENT2       WTHHFIN     WTHHFIN5D     WTHHFIN2D  CNTTDHH  PPT517  \
# 0              55   4683.562599      0.000000  14269.464209        7       2
# 1              70   2953.682712   3785.827852      0.000000        6       0
# 2              40   9609.157141  12211.967921      0.000000        2       2
# 3              50   4771.408635   6848.795739      0.000000        0       0
# 4              80   7518.766643  10909.476884      0.000000        4       0
# ...           ...           ...           ...           ...      ...     ...
# 7066           30   7050.553764  10969.283328      0.000000        5       2
# 7067            0   8192.198394  10973.908554      0.000000        3       0
# 7068            0   2631.696341      0.000000  17381.268571        0       0
# 7069            0  12857.670012  17381.711443      0.000000        0       0
# 7070           40   9267.498350  11276.180670      0.000000        3       0
#
#       YOUNGCHILD  RESP_CNT  WRKCOUNT  NUMADLT  RIDESHARE22  DRVRCNT  HHSIZE  \
# 0              0         4         1        2            0        2       4
# 1              0         2         2        2            0        2       2
# 2              0         4         1        2            0        2       4
# 3              0         1         1        1            0        1       1
# 4              1         2         2        2            3        2       3
# ...          ...       ...       ...      ...          ...      ...     ...
# 7066           0         3         1        1            0        1       3
# 7067           0         2         0        2            0        1       2
# 7068           0         1         0        1            0        1       1
# 7069           0         2         0        2            0        2       2
# 7070           0         1         1        1            0        1       1
#
#       HHVEHCNT
# 0            2
# 1            1
# 2            1
# 3            1
# 4            2
# ...        ...
# 7066         2
# 7067         1
# 7068         1
# 7069         2
# 7070         1
#
# [7071 rows x 20 columns]
# Index(['TAXISERVICE', 'ESCOOTERUSED', 'PTUSED', 'MCTRANSIT', 'WALKTRANSIT',
#        'BIKETRANSIT', 'EMPLOYMENT2', 'WTHHFIN', 'WTHHFIN5D', 'WTHHFIN2D',
#        'CNTTDHH', 'PPT517', 'YOUNGCHILD', 'RESP_CNT', 'WRKCOUNT', 'NUMADLT',
#        'RIDESHARE22', 'DRVRCNT', 'HHSIZE', 'HHVEHCNT'],
#       dtype='object')

# %%
encoded = pd.concat([df_categorical, df_numerical], axis=1)
encoded
# Out:
#                                             HighestEDUC  \
# 0     [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 1     [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 2     [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 3     [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 4     [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# ...                                                 ...
# 7066  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7067  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7068  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7069  [tensor(0.), tensor(1.), tensor(0.), tensor(0....
# 7070  [tensor(0.), tensor(0.), tensor(0.), tensor(1....
#
#                                                HOMEOWN  \
# 0     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 1     [tensor(0.), tensor(0.), tensor(1.), tensor(0.)]
# 2     [tensor(0.), tensor(0.), tensor(1.), tensor(0.)]
# 3     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 4     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# ...                                                ...
# 7066  [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 7067  [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 7068  [tensor(0.), tensor(1.), tensor(0.), tensor(0.)]
# 7069  [tensor(0.), tensor(1.), tensor(0.), tensor(0.)]
# 7070  [tensor(0.), tensor(1.), tensor(0.), tensor(0.)]
#
#                                                HOMETYPE  \
# 0     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 1     [tensor(0.), tensor(0.), tensor(1.), tensor(0....
# 2     [tensor(0.), tensor(0.), tensor(1.), tensor(0....
# 3     [tensor(0.), tensor(1.), tensor(0.), tensor(0....
# 4     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# ...                                                 ...
# 7066  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 7067  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 7068  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 7069  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 7070  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
#
#                                                 TRAVDAY  \
# 0     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 1     [tensor(0.), tensor(0.), tensor(0.), tensor(1....
# 2     [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 3     [tensor(0.), tensor(1.), tensor(0.), tensor(0....
# 4     [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# ...                                                 ...
# 7066  [tensor(0.), tensor(1.), tensor(0.), tensor(0....
# 7067  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7068  [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 7069  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7070  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
#
#                           RAIL  \
# 0     [tensor(1.), tensor(0.)]
# 1     [tensor(0.), tensor(1.)]
# 2     [tensor(1.), tensor(0.)]
# 3     [tensor(0.), tensor(1.)]
# 4     [tensor(1.), tensor(0.)]
# ...                        ...
# 7066  [tensor(0.), tensor(1.)]
# 7067  [tensor(0.), tensor(1.)]
# 7068  [tensor(0.), tensor(1.)]
# 7069  [tensor(0.), tensor(1.)]
# 7070  [tensor(0.), tensor(1.)]
#
#                                                CENSUS_D  \
# 0     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 1     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 2     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 3     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# 4     [tensor(1.), tensor(0.), tensor(0.), tensor(0....
# ...                                                 ...
# 7066  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7067  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7068  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7069  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
# 7070  [tensor(0.), tensor(0.), tensor(0.), tensor(0....
#
#                                               CENSUS_R  \
# 0     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 1     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 2     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 3     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# 4     [tensor(1.), tensor(0.), tensor(0.), tensor(0.)]
# ...                                                ...
# 7066  [tensor(0.), tensor(0.), tensor(1.), tensor(0.)]
# 7067  [tensor(0.), tensor(0.), tensor(1.), tensor(0.)]
# 7068  [tensor(0.), tensor(0.), tensor(1.), tensor(0.)]
# 7069  [tensor(0.), tensor(0.), tensor(1.), tensor(0.)]
# 7070  [tensor(0.), tensor(0.), tensor(1.), tensor(0.)]
#
#                        HH_HISP                   FLAG100  \
# 0     [tensor(0.), tensor(1.)]  [tensor(1.), tensor(0.)]
# 1     [tensor(0.), tensor(1.)]  [tensor(1.), tensor(0.)]
# 2     [tensor(0.), tensor(1.)]  [tensor(1.), tensor(0.)]
# 3     [tensor(0.), tensor(1.)]  [tensor(1.), tensor(0.)]
# 4     [tensor(0.), tensor(1.)]  [tensor(1.), tensor(0.)]
# ...                        ...                       ...
# 7066  [tensor(0.), tensor(1.)]  [tensor(1.), tensor(0.)]
# 7067  [tensor(0.), tensor(1.)]  [tensor(1.), tensor(0.)]
# 7068  [tensor(0.), tensor(1.)]  [tensor(1.), tensor(0.)]
# 7069  [tensor(0.), tensor(1.)]  [tensor(1.), tensor(0.)]
# 7070  [tensor(0.), tensor(1.)]  [tensor(1.), tensor(0.)]
#
#                                                HHFAMINC  ... CNTTDHH PPT517  \
# 0     [tensor(0.), tensor(0.), tensor(0.), tensor(0....  ...       7      2
# 1     [tensor(0.), tensor(0.), tensor(0.), tensor(0....  ...       6      0
# 2     [tensor(0.), tensor(0.), tensor(0.), tensor(0....  ...       2      2
# 3     [tensor(0.), tensor(0.), tensor(0.), tensor(0....  ...       0      0
# 4     [tensor(0.), tensor(0.), tensor(0.), tensor(0....  ...       4      0
# ...                                                 ...  ...     ...    ...
# 7066  [tensor(0.), tensor(0.), tensor(0.), tensor(0....  ...       5      2
# 7067  [tensor(0.), tensor(0.), tensor(1.), tensor(0....  ...       3      0
# 7068  [tensor(0.), tensor(0.), tensor(0.), tensor(1....  ...       0      0
# 7069  [tensor(0.), tensor(0.), tensor(0.), tensor(1....  ...       0      0
# 7070  [tensor(0.), tensor(0.), tensor(0.), tensor(0....  ...       3      0
#
#      YOUNGCHILD RESP_CNT WRKCOUNT NUMADLT RIDESHARE22 DRVRCNT HHSIZE HHVEHCNT
# 0             0        4        1       2           0       2      4        2
# 1             0        2        2       2           0       2      2        1
# 2             0        4        1       2           0       2      4        1
# 3             0        1        1       1           0       1      1        1
# 4             1        2        2       2           3       2      3        2
# ...         ...      ...      ...     ...         ...     ...    ...      ...
# 7066          0        3        1       1           0       1      3        2
# 7067          0        2        0       2           0       1      2        1
# 7068          0        1        0       1           0       1      1        1
# 7069          0        2        0       2           0       2      2        2
# 7070          0        1        1       1           0       1      1        1
#
# [7071 rows x 41 columns]

# %%
# Convert object type columns to float64

lst = []
for i in range(len(df)):
    lst.append([])
    for col in df_categorical.columns:
        lst[i] = lst[i] + df_categorical[col][i].tolist()

for i in range(len(df)):
    for col in df_numerical.columns:
        lst[i].append(df[col][i])


features = torch.tensor(lst, dtype=torch.float32)
labels = torch.tensor(df['GASUSGE'], dtype=torch.float32)

# %%
feature_names = []

for col in df_categorical.columns:
    feature_names = feature_names + [col + str(i) for i in range(1, freature_lengths[col] + 1)]

feature_names = feature_names + df_numerical.columns.tolist()

# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.linear_model import RidgeCV

ridge = RidgeCV(alphas=np.logspace(-6, 6, num=5)).fit(features, labels)
importance = np.abs(ridge.coef_)
plt.bar(height=importance, x=feature_names)
plt.title("Feature importances via coefficients")
plt.show()
